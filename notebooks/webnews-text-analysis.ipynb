# %% [markdown]
# **Note:** *This notebook let you analyse a collection of web news text (2019-22) from the National Library of Norway (NB). The notebook allows for:*
#
# - *building a corpus*
# - *visualising distribution of titles, languages and harvest dates*
# - *retrieving Keywords in Context (concordances),*
# - *calculating relative frequency of collocations for a keyword.*
#
# Data has been extracted from WARC and prepared for computational analysis with the **warc2corpus pipeline** ([Tønnessen & Birkenes, 2025](https://openhumanitiesdata.metajnl.com/articles/10.5334/johd.281#21-extracting-natural-language-from-warc)).
#
# *More information can be found in the [general information about the online newspaper corpus](https://www.nb.no/en/collection/web-archive/research/web-news-corpus/)*
# ___

# %% [markdown]
# # 0. Import `dhlab` for Python

# %% [markdown]
# First, import the necessary Python packages.<br>
# If you have not installed `dhlab` yet, you need to uncomment the first line by removing `# ` in front of `!pip install ...`.

# %%
# !pip install -U dhlab
import dhlab as dh
from dhlab import Corpus, totals, Collocations, Ngram
import plotly.express as px
import numpy as np
import pandas as df

# %% [markdown]
# ___

# %% [markdown]
# # 1. Corpus Analysis

# %% [markdown]
# A **[corpus](https://en.wikipedia.org/wiki/Text_corpus)** means a collection of texts. NB's Web News Collection (2019) has a total of more than 1.5 million texts in various languages.
#
# With `dhlab`, the class `Corpus` are used to represent metadata for each document. This includes publication title, language, harvesting date, domain name, target-uri and more. Each text also has a unique `dhlabid`, which is DHlab’s persistent URN.
#
# If you want an overview of the schema attributes that are exposed through the API, read more about the [Web News Collection](https://www.nb.no/en/collection/web-archive/research/web-news-corpus/#which-schema-attributes-can-be-used-with-the-api?).

# %% [markdown]
# ## 1.1 Build a Corpus

# %% [markdown]
# Let's build a corpus!
#
# The code cell below creates a corpus of texts containing either **korona** or **covid-19**.
#
# - `doctype="nettavis"` specifies *web news* as the document type.
# - `fulltext="covid-19 OR korona"` limits the scope to texts containing one of the specified keyword(s).
#
# To change the keyword, simply edit the value of the fulltext parameter.

# %%
corpus = dh.Corpus(doctype="nettavis", fulltext="korona OR covid-19", limit=100000)
corpus

# %% [markdown]
# ## 1.2 Insight and Visualisation

# %% [markdown]
# Before analysing a corpus, we might want some insight into the corpus we defined. Let's visualise how the texts are distributed by *publication*, *harvesting date* and *language*.

# %% [markdown]
# ### 1.2.1 Publication Titles (tree map)

# %% [markdown]
# Displaying the distribution of texts per publication and visualise the distribution using a tree map.

# %%
count_titles = corpus['title'].value_counts()

fig = px.treemap(
    path=[count_titles.index],
    values=count_titles.values,
    title='Distribution of texts per publication title',
    hover_data={'Number of texts': count_titles.values}
)

fig.show()

# %% [markdown]
# ### 1.2.2 Distribution over Time

# %% [markdown]
# Displaying the distribution of texts over time, based on harvest date. A small random offset (jitter) is applied to the x-axis (harvest date) to reduce overlap, while a random spread along the y-axis is introduced purely for visual separation.

# %%
harvestdate = df.to_datetime(corpus['timestamp'], format='%Y%m%d')

# Generate random values for spread along the y-axis
y_spread = np.random.uniform(0, 1, size=len(harvestdate))

# Add jitter (small random offset) to the harvest dates
x_jitter = harvestdate + df.to_timedelta(np.random.uniform(-2, 2, size=len(harvestdate)), unit='D')

# Create a scatter plot with jitter for better distribution
fig = px.scatter(
    x=x_jitter,
    y=y_spread,
    labels={'x': 'Harvest Date', 'y': 'Spread'},
    title='Distribution by Harvest Date',
    opacity=0.5,  # Make points semi-transparent
    size_max=5  # Increase point size
)

# Display the chart
fig.show()

# %% [markdown]
# ### 1.2.3 Distribution by Language

# %% [markdown]
# Language recognition have been run on all texts. We can therefore also inspect which languages appear in the corpus.

# %%
# Count number of texts per language code
language_distribution = corpus['langs'].value_counts()

# Create pie chart
fig = px.pie(
    values=language_distribution.values,
    names=language_distribution.index,
    title='Distribution of Languages',
    labels={'names': 'Language', 'values': 'Texts'}
)

# Display chart
fig.show()

# %% [markdown]
# ## 1.3 Export Corpus Definition

# %% [markdown]
# If you are happy with the corpus you defined, you are almost ready to advance. But first, you may want to export the corpus definition. This is especially convenient for **[research data management (RDM)](https://scienceeurope.org/our-priorities/open-science/research-data-management/)**, enabling it possible for yourself and others to reproduce the dataset.
#
# You can export the corpus definiton as both Excel and JSONL. Set the filename below and run cells to export.

# %%
# Define filename (without extension)
filename = 'corpus-covid19-OR-korona'

# Export Excel
corpus.frame.to_excel(f"{filename}.xlsx", index=False)

# Export JSONL
corpus.frame.to_json(f"{filename}.jsonl", orient='records', lines=True)

# %% [markdown]
# ___

# %% [markdown]
# ## 2. Concordances

# %% [markdown]
# When you have defined your corpus, you can extract various types of information from it.
#
# One approach is by retreiving small snippets of text with **[Keyword in Context (KWIC)](https://en.wikipedia.org/wiki/Key_Word_in_Context)**, also known as *concordances*.
#
# The code cell below retrieves concordances, with a text window of up to 12 words before and after your keyword. The keyword is highlighted in bold. (To prevent that snippets can be used to reconstruct complete texts, snippets never crosses paragraphs.)
#
# Let’s request concordances for words starting with **"dugnad"**.
#
# *Dugnad* is a Norwegian term meaning of Communal work. It is similar to the Spanish *Andecha*, Portuguese *Mutirão* and Finnish/Baltic *talkoo*. (See explaination in [Wikipedia](https://en.wikipedia.org/wiki/Communal_work#Norway))

# %%
conc_dugnad = corpus.conc(words="dugnad*")
conc_dugnad.show()

# %% [markdown]
# ### Export concordances

# %% [markdown]
# Once again, we can save the results as Excel and/or JSONL format. (Ensure to update the filename!)

# %%
# Define filename (without extension)
filename = 'concordances-dugnad'

# Export Excel
conc_dugnad.frame.to_excel(f"{filename}.xlsx", index=False)

# Export JSONL
conc_dugnad.frame.to_json(f"{filename}.jsonl", orient='records', lines=True)

# %% [markdown]
# ___

# %% [markdown]
# ## 3. Collocations and Word Frequencies
#
# **[Collocations](https://en.wikipedia.org/wiki/Collocation)** means word pairs that frequently occur together. By counting collocations for a given word, we can analyse how often or rarely different words co-occur.
#
# Some words appears frequently in any text, such as `and`, `he`/`she`, etc. To identify words that are significant within our context, we calculate the *relative frequency (RF)* of each collocate, comparing the frequency in our specific corpus with general frequency in a reference corpus.
#
# The cell below lists the words with the highest relative frequency, given a keyword in the corpus.

# %%
tot = totals(75000)  # Fetches reference corpus with common word frequency
coll = corpus.coll("dugnad").frame.sort_values(by="counts", ascending=False)  # Counts collocations for the keyword in the corpus
(coll.counts / tot.freq * 100).sort_values(ascending=False).head(20)  # Calculates relative frequency (RF) in the corpus compared to the reference corpus
